# %%
import pprint
import json

# %%
import CaboCha

# %%
c = CaboCha.Parser()

# %%
sentence = 'ゆく河の流れは絶えずして、しかももとの水にあらず。淀みに浮かぶうたかたは、かつ消えかつ結びて、久しくとどまりたるためしなし。世の中にある人とすみかと、またかくのごとし。'

# %%
tree = c.parse(sentence)

# %%
pp = pprint.PrettyPrinter(indent=4)

pp.pprint(tree)
# Out:
# <CaboCha.Tree; proxy of <Swig Object of type 'CaboCha::Tree *' at 0x111cc4f30> >

# %%
for i in range(tree.chunk_size()):
    chunk = tree.chunk(i)
    print('Chunk:', i)
    print(' Score:', chunk.score)
    print(' Link:', chunk.link)
    print(' Size:', chunk.token_size)
    print(' Pos:', chunk.token_pos)
    print(' Head:', chunk.head_pos) # 主辞
    print(' Func:', chunk.func_pos) # 機能語
    print(' Features:')
    for j in range(chunk.feature_list_size):
        print(chunk.feature_list(j))
    print('----')
# Out:
# Chunk: 0
#  Score: 0.7608441710472107
#  Link: 1
#  Size: 1
#  Pos: 0
#  Head: 0
#  Func: 0
#  Features:
# SHS:ゆく
# SHP0:動詞
# SHP1:自立
# SHF:基本形
# SFS:ゆく
# SFP0:動詞
# SFP1:自立
# SFF:基本形
# SLS:ゆく
# SLP0:動詞
# SLP1:自立
# SLF:基本形
# SRS:ゆく
# SRP0:動詞
# SRP1:自立
# SRF:基本形
# LF:ゆく
# RL:ゆく
# RH:ゆく
# RF:ゆく
# SBOS:1
# a:基本形
# ----
# Chunk: 1
#  Score: 2.25746750831604
#  Link: 2
#  Size: 2
#  Pos: 1
#  Head: 0
#  Func: 1
#  Features:
# SCASE:の
# SHS:河
# SHP0:名詞
# SHP1:一般
# SFS:の
# SFP0:助詞
# SFP1:連体化
# SLS:河
# SLP0:名詞
# SLP1:一般
# SRS:の
# SRP0:助詞
# SRP1:連体化
# LF:の
# RL:河
# RH:河
# RF:の
# GCASE:の
# a:の
# ----
# Chunk: 2
#  Score: 0.5786755084991455
#  Link: 3
#  Size: 2
#  Pos: 3
#  Head: 0
#  Func: 1
#  Features:
# SCASE:は
# SHS:流れ
# SHP0:名詞
# SHP1:一般
# SFS:は
# SFP0:助詞
# SFP1:係助詞
# SLS:流れ
# SLP0:名詞
# SLP1:一般
# SRS:は
# SRP0:助詞
# SRP1:係助詞
# LF:は
# RL:流れ
# RH:流れ
# RF:は
# GCASE:は
# a:は
# ----
# Chunk: 3
#  Score: 1.3796308040618896
#  Link: 7
#  Size: 4
#  Pos: 5
#  Head: 1
#  Func: 2
#  Features:
# SCASE:て
# GPUNC:、
# SPUNC:、
# SHS:し
# SHP0:動詞
# SHP1:自立
# SHF:連用形
# SFS:て
# SFP0:助詞
# SFP1:接続助詞
# SLS:絶えず
# SLP0:副詞
# SLP1:一般
# SRS:、
# SRP0:記号
# SRP1:読点
# LF:て
# RL:絶えず
# RH:し
# RF:て
# GCASE:て
# a:て
# ----
# Chunk: 4
#  Score: 1.8483779430389404
#  Link: 7
#  Size: 1
#  Pos: 9
#  Head: 0
#  Func: 0
#  Features:
# SHS:しかも
# SHP0:接続詞
# SFS:しかも
# SFP0:接続詞
# SLS:しかも
# SLP0:接続詞
# SRS:しかも
# SRP0:接続詞
# LF:しかも
# RL:しかも
# RH:しかも
# RF:しかも
# a:しかも
# ----
# Chunk: 5
#  Score: 0.8024792075157166
#  Link: 6
#  Size: 2
#  Pos: 10
#  Head: 0
#  Func: 1
#  Features:
# SCASE:の
# SHS:もと
# SHP0:名詞
# SHP1:一般
# SFS:の
# SFP0:助詞
# SFP1:連体化
# SLS:もと
# SLP0:名詞
# SLP1:一般
# SRS:の
# SRP0:助詞
# SRP1:連体化
# LF:の
# RL:もと
# RH:もと
# RF:の
# GCASE:の
# a:の
# ----
# Chunk: 6
#  Score: 3.3062405586242676
#  Link: 7
#  Size: 2
#  Pos: 12
#  Head: 0
#  Func: 1
#  Features:
# SCASE:に
# SHS:水
# SHP0:名詞
# SHP1:一般
# SFS:に
# SFP0:助詞
# SFP1:格助詞
# SFP2:一般
# SLS:水
# SLP0:名詞
# SLP1:一般
# SRS:に
# SRP0:助詞
# SRP1:格助詞
# SRP2:一般
# LF:に
# RL:水
# RH:水
# RF:に
# GCASE:に
# a:に
# ----
# Chunk: 7
#  Score: 0.7769230008125305
#  Link: 15
#  Size: 3
#  Pos: 14
#  Head: 0
#  Func: 1
#  Features:
# GPUNC:。
# SPUNC:。
# SHS:あら
# SHP0:動詞
# SHP1:自立
# SHF:未然形
# SFS:ず
# SFP0:助動詞
# SFF:連用ニ接続
# SLS:あら
# SLP0:動詞
# SLP1:自立
# SLF:未然形
# SRS:。
# SRP0:記号
# SRP1:句点
# LF:ず
# RL:あら
# RH:あら
# RF:ず
# a:連用ニ接続
# ----
# Chunk: 8
#  Score: 2.285391092300415
#  Link: 9
#  Size: 2
#  Pos: 17
#  Head: 0
#  Func: 1
#  Features:
# SCASE:に
# SHS:淀み
# SHP0:名詞
# SHP1:一般
# SFS:に
# SFP0:助詞
# SFP1:格助詞
# SFP2:一般
# SLS:淀み
# SLP0:名詞
# SLP1:一般
# SRS:に
# SRP0:助詞
# SRP1:格助詞
# SRP2:一般
# LF:に
# RL:淀み
# RH:淀み
# RF:に
# GCASE:に
# a:に
# ----
# Chunk: 9
#  Score: 0.6476126909255981
#  Link: 10
#  Size: 1
#  Pos: 19
#  Head: 0
#  Func: 0
#  Features:
# SHS:浮かぶ
# SHP0:動詞
# SHP1:自立
# SHF:基本形
# SFS:浮かぶ
# SFP0:動詞
# SFP1:自立
# SFF:基本形
# SLS:浮かぶ
# SLP0:動詞
# SLP1:自立
# SLF:基本形
# SRS:浮かぶ
# SRP0:動詞
# SRP1:自立
# SRF:基本形
# LF:浮かぶ
# RL:浮かぶ
# RH:浮かぶ
# RF:浮かぶ
# a:基本形
# ----
# Chunk: 10
#  Score: 0.4234001040458679
#  Link: 11
#  Size: 4
#  Pos: 20
#  Head: 3
#  Func: 3
#  Features:
# SCASE:は
# GPUNC:、
# SPUNC:、
# SHS:かつ
# SHP0:接続詞
# SFS:かつ
# SFP0:接続詞
# SLS:うたかた
# SLP0:名詞
# SLP1:一般
# SRS:かつ
# SRP0:接続詞
# LF:かつ
# RL:うたかた
# RH:かつ
# RF:かつ
# a:かつ
# ----
# Chunk: 11
#  Score: 1.8498433828353882
#  Link: 12
#  Size: 2
#  Pos: 24
#  Head: 1
#  Func: 1
#  Features:
# SHS:かつ
# SHP0:接続詞
# SFS:かつ
# SFP0:接続詞
# SLS:消え
# SLP0:動詞
# SLP1:自立
# SLF:連用形
# SRS:かつ
# SRP0:接続詞
# LF:かつ
# RL:消え
# RH:かつ
# RF:かつ
# a:かつ
# ----
# Chunk: 12
#  Score: 0.18693242967128754
#  Link: 14
#  Size: 3
#  Pos: 26
#  Head: 0
#  Func: 1
#  Features:
# SCASE:て
# GPUNC:、
# SPUNC:、
# SHS:結び
# SHP0:動詞
# SHP1:自立
# SHF:連用形
# SFS:て
# SFP0:助詞
# SFP1:接続助詞
# SLS:結び
# SLP0:動詞
# SLP1:自立
# SLF:連用形
# SRS:、
# SRP0:記号
# SRP1:読点
# LF:て
# RL:結び
# RH:結び
# RF:て
# GCASE:て
# a:て
# ----
# Chunk: 13
#  Score: 1.2079802751541138
#  Link: 14
#  Size: 1
#  Pos: 29
#  Head: 0
#  Func: 0
#  Features:
# SHS:久しく
# SHP0:形容詞
# SHP1:自立
# SHF:連用テ接続
# SFS:久しく
# SFP0:形容詞
# SFP1:自立
# SFF:連用テ接続
# SLS:久しく
# SLP0:形容詞
# SLP1:自立
# SLF:連用テ接続
# SRS:久しく
# SRP0:形容詞
# SRP1:自立
# SRF:連用テ接続
# LF:久しく
# RL:久しく
# RH:久しく
# RF:久しく
# a:連用テ接続
# ----
# Chunk: 14
#  Score: 1.8378452062606812
#  Link: 15
#  Size: 2
#  Pos: 30
#  Head: 0
#  Func: 1
#  Features:
# SHS:とどまり
# SHP0:動詞
# SHP1:自立
# SHF:連用形
# SFS:たる
# SFP0:助動詞
# SFF:体言接続
# SLS:とどまり
# SLP0:動詞
# SLP1:自立
# SLF:連用形
# SRS:たる
# SRP0:助動詞
# SRF:体言接続
# LF:たる
# RL:とどまり
# RH:とどまり
# RF:たる
# a:体言接続
# ----
# Chunk: 15
#  Score: -0.7627430558204651
#  Link: 20
#  Size: 3
#  Pos: 32
#  Head: 1
#  Func: 1
#  Features:
# GPUNC:。
# SPUNC:。
# SHS:なし
# SHP0:形容詞
# SHP1:自立
# SHF:文語基本形
# SFS:なし
# SFP0:形容詞
# SFP1:自立
# SFF:文語基本形
# SLS:ためし
# SLP0:名詞
# SLP1:一般
# SRS:。
# SRP0:記号
# SRP1:句点
# LF:なし
# RL:ためし
# RH:なし
# RF:なし
# A:文語基本形
# ----
# Chunk: 16
#  Score: 1.9035781621932983
#  Link: 17
#  Size: 2
#  Pos: 35
#  Head: 0
#  Func: 1
#  Features:
# SCASE:に
# SHS:世の中
# SHP0:名詞
# SHP1:一般
# SFS:に
# SFP0:助詞
# SFP1:格助詞
# SFP2:一般
# SLS:世の中
# SLP0:名詞
# SLP1:一般
# SRS:に
# SRP0:助詞
# SRP1:格助詞
# SRP2:一般
# LF:に
# RL:世の中
# RH:世の中
# RF:に
# GCASE:に
# a:に
# ----
# Chunk: 17
#  Score: 0.4326143264770508
#  Link: 18
#  Size: 1
#  Pos: 37
#  Head: 0
#  Func: 0
#  Features:
# SHS:ある
# SHP0:動詞
# SHP1:自立
# SHF:基本形
# SFS:ある
# SFP0:動詞
# SFP1:自立
# SFF:基本形
# SLS:ある
# SLP0:動詞
# SLP1:自立
# SLF:基本形
# SRS:ある
# SRP0:動詞
# SRP1:自立
# SRF:基本形
# LF:ある
# RL:ある
# RH:ある
# RF:ある
# a:基本形
# ----
# Chunk: 18
#  Score: 1.2576225996017456
#  Link: 19
#  Size: 2
#  Pos: 38
#  Head: 0
#  Func: 1
#  Features:
# SCASE:と
# SHS:人
# SHP0:名詞
# SHP1:一般
# SFS:と
# SFP0:助詞
# SFP1:並立助詞
# SLS:人
# SLP0:名詞
# SLP1:一般
# SRS:と
# SRP0:助詞
# SRP1:並立助詞
# LF:と
# RL:人
# RH:人
# RF:と
# GCASE:と
# A:と
# ----
# Chunk: 19
#  Score: -0.7627430558204651
#  Link: 20
#  Size: 4
#  Pos: 40
#  Head: 3
#  Func: 3
#  Features:
# DCASE:と
# GPUNC:、
# DPUNC:、
# DHS:また
# DHP0:接続詞
# DFS:また
# DFP0:接続詞
# DLS:すみか
# DLP0:名詞
# DLP1:一般
# DRS:また
# DRP0:接続詞
# LF:また
# RL:すみか
# RH:また
# RF:また
# A:また
# ----
# Chunk: 20
#  Score: 0.0
#  Link: -1
#  Size: 4
#  Pos: 44
#  Head: 1
#  Func: 2
#  Features:
# GPUNC:。
# FPUNC:。
# FHS:の
# FHP0:名詞
# FHP1:非自立
# FHP2:一般
# FFS:ごとし
# FFP0:助動詞
# FFF:基本形
# FLS:かく
# FLP0:動詞
# FLP1:自立
# FLF:基本形
# FRS:。
# FRP0:記号
# FRP1:句点
# LF:ごとし
# RL:かく
# RH:の
# RF:ごとし
# FEOS:1
# A:基本形
# ----

# %%
for i in range(tree.token_size()):
    token = tree.token(i)
    print('Surface:', token.surface)
    print(' Normalized:', token.normalized_surface)
    print(' Feature:', token.feature)
    print(' NE:', token.ne) # 固有表現
    print(' Info:', token.additional_info)
    print(' Chunk:', token.chunk)
    print('----')
# Out:
# Surface: ゆく
#  Normalized: ゆく
#  Feature: 動詞,自立,*,*,五段・カ行促音便ユク,基本形,ゆく,ユク,ユク
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b210> >
# ----
# Surface: 河
#  Normalized: 河
#  Feature: 名詞,一般,*,*,*,*,河,カワ,カワ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111cc4570> >
# ----
# Surface: の
#  Normalized: の
#  Feature: 助詞,連体化,*,*,*,*,の,ノ,ノ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 流れ
#  Normalized: 流れ
#  Feature: 名詞,一般,*,*,*,*,流れ,ナガレ,ナガレ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111cc41e0> >
# ----
# Surface: は
#  Normalized: は
#  Feature: 助詞,係助詞,*,*,*,*,は,ハ,ワ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 絶えず
#  Normalized: 絶えず
#  Feature: 副詞,一般,*,*,*,*,絶えず,タエズ,タエズ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6bd80> >
# ----
# Surface: し
#  Normalized: し
#  Feature: 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: て
#  Normalized: て
#  Feature: 助詞,接続助詞,*,*,*,*,て,テ,テ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 、
#  Normalized: 、
#  Feature: 記号,読点,*,*,*,*,、,、,、
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: しかも
#  Normalized: しかも
#  Feature: 接続詞,*,*,*,*,*,しかも,シカモ,シカモ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111cc4cc0> >
# ----
# Surface: もと
#  Normalized: もと
#  Feature: 名詞,一般,*,*,*,*,もと,モト,モト
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6be40> >
# ----
# Surface: の
#  Normalized: の
#  Feature: 助詞,連体化,*,*,*,*,の,ノ,ノ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 水
#  Normalized: 水
#  Feature: 名詞,一般,*,*,*,*,水,ミズ,ミズ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b390> >
# ----
# Surface: に
#  Normalized: に
#  Feature: 助詞,格助詞,一般,*,*,*,に,ニ,ニ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: あら
#  Normalized: あら
#  Feature: 動詞,自立,*,*,五段・ラ行,未然形,ある,アラ,アラ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111c54f90> >
# ----
# Surface: ず
#  Normalized: ず
#  Feature: 助動詞,*,*,*,特殊・ヌ,連用ニ接続,ぬ,ズ,ズ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 。
#  Normalized: 。
#  Feature: 記号,句点,*,*,*,*,。,。,。
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 淀み
#  Normalized: 淀み
#  Feature: 名詞,一般,*,*,*,*,淀み,ヨドミ,ヨドミ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b630> >
# ----
# Surface: に
#  Normalized: に
#  Feature: 助詞,格助詞,一般,*,*,*,に,ニ,ニ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 浮かぶ
#  Normalized: 浮かぶ
#  Feature: 動詞,自立,*,*,五段・バ行,基本形,浮かぶ,ウカブ,ウカブ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b900> >
# ----
# Surface: うたかた
#  Normalized: うたかた
#  Feature: 名詞,一般,*,*,*,*,うたかた,ウタカタ,ウタカタ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6bd20> >
# ----
# Surface: は
#  Normalized: は
#  Feature: 助詞,係助詞,*,*,*,*,は,ハ,ワ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 、
#  Normalized: 、
#  Feature: 記号,読点,*,*,*,*,、,、,、
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: かつ
#  Normalized: かつ
#  Feature: 接続詞,*,*,*,*,*,かつ,カツ,カツ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 消え
#  Normalized: 消え
#  Feature: 動詞,自立,*,*,一段,連用形,消える,キエ,キエ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b995a0> >
# ----
# Surface: かつ
#  Normalized: かつ
#  Feature: 接続詞,*,*,*,*,*,かつ,カツ,カツ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 結び
#  Normalized: 結び
#  Feature: 動詞,自立,*,*,五段・バ行,連用形,結ぶ,ムスビ,ムスビ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111cc4ea0> >
# ----
# Surface: て
#  Normalized: て
#  Feature: 助詞,接続助詞,*,*,*,*,て,テ,テ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 、
#  Normalized: 、
#  Feature: 記号,読点,*,*,*,*,、,、,、
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 久しく
#  Normalized: 久しく
#  Feature: 形容詞,自立,*,*,形容詞・イ段,連用テ接続,久しい,ヒサシク,ヒサシク
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b8f0c0> >
# ----
# Surface: とどまり
#  Normalized: とどまり
#  Feature: 動詞,自立,*,*,五段・ラ行,連用形,とどまる,トドマリ,トドマリ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b8fa80> >
# ----
# Surface: たる
#  Normalized: たる
#  Feature: 助動詞,*,*,*,文語・ナリ,体言接続,たり,タル,タル
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: ためし
#  Normalized: ためし
#  Feature: 名詞,一般,*,*,*,*,ためし,タメシ,タメシ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b8f360> >
# ----
# Surface: なし
#  Normalized: なし
#  Feature: 形容詞,自立,*,*,形容詞・アウオ段,文語基本形,ない,ナシ,ナシ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 。
#  Normalized: 。
#  Feature: 記号,句点,*,*,*,*,。,。,。
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 世の中
#  Normalized: 世の中
#  Feature: 名詞,一般,*,*,*,*,世の中,ヨノナカ,ヨノナカ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b240> >
# ----
# Surface: に
#  Normalized: に
#  Feature: 助詞,格助詞,一般,*,*,*,に,ニ,ニ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: ある
#  Normalized: ある
#  Feature: 動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b450> >
# ----
# Surface: 人
#  Normalized: 人
#  Feature: 名詞,一般,*,*,*,*,人,ヒト,ヒト
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b480> >
# ----
# Surface: と
#  Normalized: と
#  Feature: 助詞,並立助詞,*,*,*,*,と,ト,ト
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: すみか
#  Normalized: すみか
#  Feature: 名詞,一般,*,*,*,*,すみか,スミカ,スミカ
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x116b6b8d0> >
# ----
# Surface: と
#  Normalized: と
#  Feature: 助詞,並立助詞,*,*,*,*,と,ト,ト
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 、
#  Normalized: 、
#  Feature: 記号,読点,*,*,*,*,、,、,、
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: また
#  Normalized: また
#  Feature: 接続詞,*,*,*,*,*,また,マタ,マタ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: かく
#  Normalized: かく
#  Feature: 動詞,自立,*,*,五段・カ行イ音便,基本形,かく,カク,カク
#  NE: None
#  Info: None
#  Chunk: <CaboCha.Chunk; proxy of <Swig Object of type 'CaboCha::Chunk *' at 0x111c54cf0> >
# ----
# Surface: の
#  Normalized: の
#  Feature: 名詞,非自立,一般,*,*,*,の,ノ,ノ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: ごとし
#  Normalized: ごとし
#  Feature: 助動詞,*,*,*,文語・ゴトシ,基本形,ごとし,ゴトシ,ゴトシ
#  NE: None
#  Info: None
#  Chunk: None
# ----
# Surface: 。
#  Normalized: 。
#  Feature: 記号,句点,*,*,*,*,。,。,。
#  NE: None
#  Info: None
#  Chunk: None
# ----

# %%
cabocha_text = tree.toString(CaboCha.FORMAT_LATTICE)

# %%
import pydotplus

# %%
def make_analyzed_file(input_file_name: str, output_file_name: str) -> None:
    """
    プレーンな日本語の文章ファイルを係り受け解析してファイルに保存する.
    (空白は削除します.)
    :param input_file_name プレーンな日本語の文章ファイル名
    :param output_file_name 係り受け解析済みの文章ファイル名
    """
    c = CaboCha.Parser()
    with open(input_file_name, encoding='utf-8') as input_file:
        with open(output_file_name, mode='w', encoding='utf-8') as output_file:
            for line in input_file:
                tree = c.parse(line.lstrip())
                output_file.write(tree.toString(CaboCha.FORMAT_LATTICE))


make_analyzed_file('neko.txt', 'neko.txt.cabocha')

# %%
class Morph:
    """
    1つの形態素を表すクラス
    """

    def __init__(self, surface, base, pos, pos1):
        """
        メンバ変数として表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）を持つ.
        """
        self.surface = surface
        self.base = base
        self.pos = pos
        self.pos1 = pos1

    def is_end_of_sentence(self) -> bool: return self.pos1 == '句点'

    def __str__(self) -> str: return 'surface: {}, base: {}, pos: {}, pos1: {}'.format(self.surface, self.base, self.pos, self.pos1)


def make_morph_list(analyzed_file_name: str) -> list:
    """
    係り受け解析済みの文章ファイルを読み込んで、各文をMorphオブジェクトのリストとして表現する
    :param analyzed_file_name 係り受け解析済みの文章ファイル名
    :return list 一つの文章をMorphオブジェクトのリストとして表現したもののリスト
    """
    sentences = []
    sentence = []
    with open(analyzed_file_name, encoding='utf-8') as input_file:
        for line in input_file:
            line_list = line.split()
            if (line_list[0] == '*') | (line_list[0] == 'EOS'):
                pass
            else:
                line_list = line_list[0].split(',') + line_list[1].split(',')
                # この時点でline_listはこんな感じ
                # ['始め', '名詞', '副詞可能', '*', '*', '*', '*', '始め', 'ハジメ', 'ハジメ']
                _morph = Morph(surface=line_list[0], base=line_list[7], pos=line_list[1], pos1=line_list[2])

                sentence.append(_morph)

                if _morph.is_end_of_sentence():
                    sentences.append(sentence)
                    sentence = []

    return sentences


morphed_sentences = make_morph_list('neko.txt.cabocha')

# 3文目の形態素列を表示
for morph in morphed_sentences[2]:
    print(str(morph))
# Out:
# surface: 世の中, base: 世の中, pos: 名詞, pos1: 一般
# surface: に, base: に, pos: 助詞, pos1: 格助詞
# surface: ある, base: ある, pos: 動詞, pos1: 自立
# surface: 人, base: 人, pos: 名詞, pos1: 一般
# surface: と, base: と, pos: 助詞, pos1: 並立助詞
# surface: すみか, base: すみか, pos: 名詞, pos1: 一般
# surface: と, base: と, pos: 助詞, pos1: 並立助詞
# surface: 、, base: 、, pos: 記号, pos1: 読点
# surface: また, base: また, pos: 接続詞, pos1: *
# surface: かく, base: かく, pos: 動詞, pos1: 自立
# surface: の, base: の, pos: 名詞, pos1: 非自立
# surface: ごとし, base: ごとし, pos: 助動詞, pos1: *
# surface: 。, base: 。, pos: 記号, pos1: 句点

# %%
class Chunk:
    def __init__(self, morphs: list, dst: str, srcs: str) -> None:
        """
        形態素（Morphオブジェクト）のリスト（morphs），係り先文節インデックス番号（dst），係り元文節インデックス番号のリスト（srcs）をメンバ変数に持つ
        """
        self.morphs = morphs
        self.dst = int(dst.strip("D"))
        self.srcs = int(srcs)

    # 以下は後々使うメソッドです.
    def join_morphs(self) -> str:
        return ''.join([_morph.surface for _morph in self.morphs if _morph.pos != '記号'])

    def has_noun(self) -> bool:
        return any([_morph.pos == '名詞' for _morph in self.morphs])

    def has_verb(self) -> bool:
        return any([_morph.pos == '動詞' for _morph in self.morphs])

    def has_particle(self) -> bool:
        return any([_morph.pos == '助詞' for _morph in self.morphs])

    def has_sahen_connection_noun_plus_wo(self) -> bool:
        """
        「サ変接続名詞+を（助詞）」を含むかどうかを返す.
        """
        for idx, _morph in enumerate(self.morphs):
            if _morph.pos == '名詞' and _morph.pos1 == 'サ変接続' and len(self.morphs[idx:]) > 1 and \
                            self.morphs[idx + 1].pos == '助詞' and self.morphs[idx + 1].base == 'を':
                return True

        return False

    def first_verb(self) -> Morph:
        return [_morph for _morph in self.morphs if _morph.pos == '動詞'][0]

    def last_particle(self) -> list:
        return [_morph for _morph in self.morphs if _morph.pos == '助詞'][-1]

    def pair(self, sentence: list) -> str:
        return self.join_morphs() + '\t' + sentence[self.dst].join_morphs()

    def replace_noun(self, alt: str) -> None:
        """
        名詞の表象を置換する.
        """
        for _morph in self.morphs:
            if _morph.pos == '名詞':
                _morph.surface = alt

    def __str__(self) -> str:
        return 'srcs: {}, dst: {}, morphs: ({})'.format(self.srcs, self.dst, ' / '.join([str(_morph) for _morph in self.morphs]))


def make_chunk_list(analyzed_file_name: str) -> list:
    """
    係り受け解析済みの文章ファイルを読み込んで、各文をChunkオブジェクトのリストとして表現する
    :param analyzed_file_name 係り受け解析済みの文章ファイル名
    :return list 一つの文章をChunkオブジェクトのリストとして表現したもののリスト
    """
    sentences = []
    sentence = []
    _chunk = None
    with open(analyzed_file_name, encoding='utf-8') as input_file:
        for line in input_file:
            line_list = line.split()
            if line_list[0] == '*':
                if _chunk is not None:
                    sentence.append(_chunk)
                _chunk = Chunk(morphs=[], dst=line_list[2], srcs=line_list[1])
            elif line_list[0] == 'EOS':  # End of sentence
                if _chunk is not None:
                    sentence.append(_chunk)
                if len(sentence) > 0:
                    sentences.append(sentence)
                _chunk = None
                sentence = []
            else:
                line_list = line_list[0].split(',') + line_list[1].split(',')
                # この時点でline_listはこんな感じ
                # ['始め', '名詞', '副詞可能', '*', '*', '*', '*', '始め', 'ハジメ', 'ハジメ']
                _morph = Morph(surface=line_list[0], base=line_list[7], pos=line_list[1], pos1=line_list[2])
                _chunk.morphs.append(_morph)

    return sentences


chunked_sentences = make_chunk_list('neko.txt.cabocha')

# 3文目の形態素列を表示
for chunk in chunked_sentences[0]:
    #print(str(chunk))
# Out:
# srcs: 0, dst: 1, morphs: (surface: ゆく, base: ゆく, pos: 動詞, pos1: 自立)
# srcs: 1, dst: 2, morphs: (surface: 河, base: 河, pos: 名詞, pos1: 一般 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# srcs: 2, dst: 3, morphs: (surface: 流れ, base: 流れ, pos: 名詞, pos1: 一般 / surface: は, base: は, pos: 助詞, pos1: 係助詞)
# srcs: 3, dst: 7, morphs: (surface: 絶えず, base: 絶えず, pos: 副詞, pos1: 一般 / surface: し, base: する, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# srcs: 4, dst: 7, morphs: (surface: しかも, base: しかも, pos: 接続詞, pos1: *)
# srcs: 5, dst: 6, morphs: (surface: もと, base: もと, pos: 名詞, pos1: 一般 / surface: の, base: の, pos: 助詞, pos1: 連体化)
# srcs: 6, dst: 7, morphs: (surface: 水, base: 水, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# srcs: 7, dst: 15, morphs: (surface: あら, base: ある, pos: 動詞, pos1: 自立 / surface: ず, base: ぬ, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)
# srcs: 8, dst: 9, morphs: (surface: 淀み, base: 淀み, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# srcs: 9, dst: 10, morphs: (surface: 浮かぶ, base: 浮かぶ, pos: 動詞, pos1: 自立)
# srcs: 10, dst: 11, morphs: (surface: うたかた, base: うたかた, pos: 名詞, pos1: 一般 / surface: は, base: は, pos: 助詞, pos1: 係助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点 / surface: かつ, base: かつ, pos: 接続詞, pos1: *)
# srcs: 11, dst: 12, morphs: (surface: 消え, base: 消える, pos: 動詞, pos1: 自立 / surface: かつ, base: かつ, pos: 接続詞, pos1: *)
# srcs: 12, dst: 14, morphs: (surface: 結び, base: 結ぶ, pos: 動詞, pos1: 自立 / surface: て, base: て, pos: 助詞, pos1: 接続助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点)
# srcs: 13, dst: 14, morphs: (surface: 久しく, base: 久しい, pos: 形容詞, pos1: 自立)
# srcs: 14, dst: 15, morphs: (surface: とどまり, base: とどまる, pos: 動詞, pos1: 自立 / surface: たる, base: たり, pos: 助動詞, pos1: *)
# srcs: 15, dst: 20, morphs: (surface: ためし, base: ためし, pos: 名詞, pos1: 一般 / surface: なし, base: ない, pos: 形容詞, pos1: 自立 / surface: 。, base: 。, pos: 記号, pos1: 句点)
# srcs: 16, dst: 17, morphs: (surface: 世の中, base: 世の中, pos: 名詞, pos1: 一般 / surface: に, base: に, pos: 助詞, pos1: 格助詞)
# srcs: 17, dst: 18, morphs: (surface: ある, base: ある, pos: 動詞, pos1: 自立)
# srcs: 18, dst: 19, morphs: (surface: 人, base: 人, pos: 名詞, pos1: 一般 / surface: と, base: と, pos: 助詞, pos1: 並立助詞)
# srcs: 19, dst: 20, morphs: (surface: すみか, base: すみか, pos: 名詞, pos1: 一般 / surface: と, base: と, pos: 助詞, pos1: 並立助詞 / surface: 、, base: 、, pos: 記号, pos1: 読点 / surface: また, base: また, pos: 接続詞, pos1: *)
# srcs: 20, dst: -1, morphs: (surface: かく, base: かく, pos: 動詞, pos1: 自立 / surface: の, base: の, pos: 名詞, pos1: 非自立 / surface: ごとし, base: ごとし, pos: 助動詞, pos1: * / surface: 。, base: 。, pos: 記号, pos1: 句点)

# %%
def is_valid_chunk(_chunk, sentence):
    return _chunk.join_morphs() != '' and _chunk.dst > -1 and sentence[_chunk.dst].join_morphs() != ''


paired_sentences = [[chunk.pair(sentence) for chunk in sentence if is_valid_chunk(chunk, sentence)] for sentence in chunked_sentences if len(sentence) > 1]
print(paired_sentences[0:100])
# Out:
# [['ゆく\t河の', '河の\t流れは', '流れは\t絶えずして', '絶えずして\tあらず', 'しかも\tあらず', 'もとの\t水に', '水に\tあらず', 'あらず\tためしなし', '淀みに\t浮かぶ', '浮かぶ\tうたかたはかつ', 'うたかたはかつ\t消えかつ', '消えかつ\t結びて', '結びて\tとどまりたる', '久しく\tとどまりたる', 'とどまりたる\tためしなし', 'ためしなし\tかくのごとし', '世の中に\tある', 'ある\t人と', '人と\tすみかとまた', 'すみかとまた\tかくのごとし'], ['たま\tものなれど', 'しきの\t都の', '都の\tうちに', 'うちに\tものなれど', '棟を\t並べ', '並べ\t争へる', '甍を\t争へる', '争へる\tものなれど', '高き\t卑しき', '卑しき\tものなれど', '人の\tすまひは', 'すまひは\tものなれど', '世々を\t経て', '経て\t尽きせぬ', '尽きせぬ\tものなれど', 'ものなれど\tまれなり', 'これを\tことかと', 'ま\tことかと', 'ことかと\t尋ぬれば', '尋ぬれば\tまれなり', '昔\tありし', 'ありし\t家は', '家は\tまれなり', 'まれなり\t作れり', 'あるいは\t作れり', '去年\t焼けて', '焼けて\t作れり', '今年\t作れり', '作れり\tなる', 'あるいは\tなる', '大家\t滅びて', '滅びて\tなる', '小家と\tなる', 'なる\t同じ', '住む\t人も', '人も\t同じ', 'これに\t同じ', '同じ\tひとりふたりなり', '所も\t変はらず', '変はらず\t多かれど', '人も\t多かれど', '多かれど\tひとりふたりなり', 'いにしへ\t見し', '見し\t人は', '人は\tひとりふたりなり', '二\t三十人が', '三十人が\tひとりふたりなり', '中に\tひとりふたりなり', 'わづかにな\tひとりふたりなり', 'ひとりふたりなり\tける', '朝に\t死に', '死に\t生まるるなら', '夕べに\t生まるるなら', '生まるるなら\tひ', 'ひ\tける', 'ただ\tける', '水の\tあわにぞ', 'あわにぞ\t似たり', '似たり\tける', 'ける\t去る', '知らず\t来たりて', '生まれ死ぬる\t人', '人\t来たりて', 'いづ\tかたより', 'かたより\t来たりて', '来たりて\t去る', 'いづかたへか\t去る', '去る\tむる', 'また\t知らず', '知らず\tむる', '仮の\t宿りたがためにか', '宿りたがためにか\t悩まし', '心を\t悩まし', '悩まし\tむる', '何により\tむる', 'てか\tむる', '目を\t喜ばし', '喜ばし\tむる', 'むる\t異ならず', 'その\t異ならず', 'あるじと\tすみかと', 'すみかと\t争ふさま', '無常を\t争ふさま', '争ふさま\t異ならず', 'いはば\t異ならず', '朝顔の\t露に', '露に\t異ならず', '異ならず\t花残れり', 'あるいは\t花残れり', '露\t落ちて', '落ちて\t花残れり', '花残れり\t枯れぬ', '残ると\tいへども', 'いへども\t枯れぬ', '朝日に\t枯れぬ', '枯れぬ\t消えず', 'あるいは\t消えず', '花\tしぼみて', 'しぼみて\t消えず', '露なほ\t消えず', '消えず\tなし', '消えずと\tいへども', 'いへども\t待つ', '夕べを\t待つ', '待つ\tこと', 'こと\tなし'], ['ＬＩＮＥは\t方針', '人工知能\t搭載した', 'を\t搭載した', '搭載した\tスピーカー向けの', 'スピーカー向けの\t技術仕様を', '技術仕様を\t公開する', '外部の\t技術者に', '企業や\t技術者に', '技術者に\t公開する', '2018年中に\t公開する', '公開する\t広げる', '外部の\t技術を', '技術を\t取り入れる', '取り入れる\tことで', 'ことで\t提供できる', '提供できる\tサービスを', 'サービスを\t広げる', '広げる\t方針', 'ＡＩなど\t先端技術には', '先端技術には\t投じる', '前年比\t３倍の', '３倍の\t300億円を', '300億円を\t投じる', '投じる\t方針', '方針\t広がりそうだ', '欧米に\t出遅れていた', '出遅れていた\tの', 'の\t開発に', '開発に\t連携しながら', '外部と\t連携しながら', '連携しながら\t取り組む', '取り組む\t動きが', '動きが\t広がりそうだ', '国内で\t広がりそうだ'], ['17年\t秋に', '秋に\t開始した', '販売を\t開始した', '開始した\tスピーカー', 'スピーカー\tクローバで', 'クローバで\t呼ばれる', 'スキルと\t呼ばれる', '呼ばれる\t機能の', '機能の\t技術仕様を', '技術仕様を\t公開する', '公開する\t開発してきた', 'これまで\t登録している', '対話アプリに\t登録している', '登録している\t人の', '人の\tスマートフォン', 'スマートフォン\tスマホと', 'スマホと\t通話する', '通話する\t機能や', '機能や\t開発してきた', '日本語を\tふき込むと', 'ふき込むと\t開発してきた', '英語や\t中国語', '中国語\t韓国語に', '韓国語に\t翻訳する', '翻訳する\t機能を', '機能を\t開発してきた', '開発してきた\tとどまる', '自社での\t取り組みには', '取り組みには\tあり', '限界が\tあり', 'あり\tとどまる', '利用できる\tスキルは', 'スキルは\tとどまる', '約20に\tとどまる'], ['外部の\t技術を', '技術を\t活用する', '活用する\tことで', 'ことで\t増やす', '迅速に\t増やす', 'サービスを\t増やす', '増やす\t想定される', 'スキルに\t盛り込んでもらいたい', '自社の\tサービスを', 'サービスを\t盛り込んでもらいたい', '盛り込んでもらいたい\t企業や', '企業や\t技術者の', 'フリーランスの\t技術者の', '技術者の\t参加を', '参加を\t見込んでおり', '見込んでおり\t想定される', 'ＡＩを通じて\t操作する', '家電を\t操作する', '操作する\t機能などの', '機能などの\t追加が', '追加が\t想定される', '想定される\tつなげる', 'スピーカーの\t利便性を', '利便性を\t高めて', '高めて\t収集し', 'ユーザーの\tデータを', 'データを\t収集し', '収集し\tつなげる', '主力の\t対話アプリの', '対話アプリの\tサービス向上にも', 'サービス向上にも\tつなげる'], ['すでに\t公開している', 'スピーカーの\t技術仕様を', '技術仕様を\t公開している', '公開している\t米アマゾンドットコムは', '米アマゾンドットコムは\t公開している', '国内で\t公開している', '487件の\tスキルを', 'スキルを\t公開している', '公開している\t増えた', '外部の\t企業から', '企業から\t相次ぎ', '技術提供が\t相次ぎ', '相次ぎ\t増えた', '昨年\t11月の', '11月の\t発売時点から', '発売時点から\t増えた', '８割\t増えた', '増えた\t利用できる', 'ＪＲ東日本の\t運行情報を', '運行情報を\t調べられる', '調べられる\t機能や', '機能や\t美容情報を', '資生堂の\t天気に', '天気に\tあわせた', 'あわせた\t美容情報を', '美容情報を\t紹介する', '紹介する\t機能などを', '機能などを\t利用できる'], ['ＬＩＮＥは\t始める', '18年には\t始める', 'ディスプレー付きの\tスピーカーの', 'スピーカーの\t販売を', '販売を\t始める', '始める\t進めている', 'トヨタ自動車など\tメーカーと', 'メーカーと\t組み', '組み\t音声を', '音声を\t認識する', '認識する\t機能を', '機能を\t搭載した', '搭載した\tウエアラブル端末の', '車載機器や\tウエアラブル端末の', 'ウエアラブル端末の\t開発も', '開発も\t進めている', '進めている\tある', '技術仕様の\t公開により', '公開により\t呼び込む', '製品の\t用途を', '用途を\t広げて', '広げて\t呼び込む', '新たな\t共同開発の', '共同開発の\tパートナーを', 'パートナーを\t呼び込む', '呼び込む\t狙いも', '狙いも\tある'], ['ＬＩＮＥは\t投じる', 'の\tほか', 'ほか\t位置付け', '情報技術を\t融合させた', '融合させた\tフィンテック分野を', 'フィンテック分野を\t位置付け', '重点分野と\t位置付け', '位置付け\t投じる', '18年に\t300億円を', '300億円を\t投じる',  ...

# %%
import graphviz
from IPython.display import Image

# %%
def sentence_to_dot(idx: int, sentence: list) -> str:
    head = "digraph sentence{} ".format(idx)
    body_head = "{ graph [rankdir = LR]; "
    body_list = ['"{}"->"{}"; '.format(*chunk_pair.split()) for chunk_pair in sentence]

    return head + body_head + ''.join(body_list) + '}'


def sentences_to_dots(sentences: list) -> list:
    _dots = []
    for idx, sentence in enumerate(sentences):
        _dots.append(sentence_to_dot(idx, sentence))
    return _dots


def save_graph(dot: str, file_name: str) -> None:
    g = pydotplus.graph_from_dot_data(dot)
    g.write_jpeg(file_name, prog='dot')
    return file_name


def show_graph(dot: str) -> None:
    g = pydotplus.graph_from_dot_data(dot)
    print(g)
    return graphviz.Source(g)

dots = sentences_to_dots(paired_sentences)

for idx in range(0, len(dots)-1):
    Image(save_graph(dots[idx], 'graph{}.jpg'.format(idx)))
    # show_graph(dots[idx])

# %%
Image('graph0.jpg')

# %%
Image('graph1.jpg')

# %%
Image('graph2.jpg')

# %%
Image('graph3.jpg')

# %%
Image('graph4.jpg')

# %%
Image('graph9.jpg')

# %%
Image('graph10.jpg')
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1190         if self.embed:
#    1191             mimetype = self._mimetype
# -> 1192             data, metadata = self._data_and_metadata(always_both=True)
#    1193             if metadata:
#    1194                 metadata = {mimetype: metadata}
#
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1199     def _data_and_metadata(self, always_both=False):
#    1200         """shortcut for returning metadata with shape information, if defined"""
# -> 1201         b64_data = b2a_base64(self.data).decode('ascii')
#    1202         md = {}
#    1203         if self.metadata:
#
# TypeError: a bytes-like object is required, not 'str'
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# <ipython-input-128-9830d6f4254a> in <module>()
# ----> 1 Image('graph10.jpg')
#
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/dev/demo/cabocha-articles/env/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     148             return {}, {}
#     149
# --> 150         format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     151
#     152         if format_dict or md_dict:
#
# TypeError: 'NoneType' object is not iterable
